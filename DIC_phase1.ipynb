# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from pathlib import Path
my_csv = Path("C:/Users/adika/OneDrive/Desktop/ub/summer23/DIC_587/project/shooting-1982-2023.csv")
df = pd.read_csv(my_csv.resolve(), sep=',')

# %%
df.head(5)
# Out:
#                                   case                   location        date  \
# 0  Nashville religious school shooting       Nashville, Tennessee   3/27/2023
# 1   Michigan State University shooting     East Lansing, Michigan   2/13/2023
# 2         Half Moon Bay spree shooting  Half Moon Bay, California   1/23/2023
# 3        LA dance studio mass shooting  Monterey Park, California   1/21/2023
# 4            Virginia Walmart shooting       Chesapeake, Virginia  11/22/2022
#
#                                              summary  fatalities  injured  \
# 0  Audrey Hale, 28, who was a former student at t...           6        1
# 1  Anthony D. McRae, 43, opened fire at Berkey Ha...           3        5
# 2  Chunli Zhao, 67, suspected of carrying out the...           7        1
# 3  Huu Can Tran, 72, fled the scene in a white va...          11       10
# 4  Andre Bing, 31, who worked as a supervisor at ...           6        6
#
#    total_victims location.1  age_of_shooter prior_signs_mental_health_issues  \
# 0              6     School              28                              NaN
# 1              8     School              43                              NaN
# 2              8       work              67                              NaN
# 3             21      Other              72                              yes
# 4             12       work              31                              NaN
#
#                                mental_health_details weapons_obtained_legally  \
# 0                                                  -                  unknown
# 1                                                  -                      yes
# 2                                                  -                  unknown
# 3  According to the LA Times, "Two law enforcemen...                  unknown
# 4                                                  -                  unknown
#
#   where_obtained                                     weapon_type  \
# 0              -      semiautomatic rifle, semiautomatic handgun
# 1              -                          semiautomatic handguns
# 2              -                           semiautomatic handgun
# 3              -  semiautomatic assault weapon (Details pending)
# 4              -                           semiautomatic handgun
#
#   weapon_details   race                                     gender   type  \
# 0              -    NaN  F (identified as transgender, per police)   Mass
# 1              -  Black                                          M   Mass
# 2              -  Asian                                          M  Spree
# 3              -  Asian                                          M   Mass
# 4              -  Black                                          M   Mass
#
#    year
# 0  2023
# 1  2023
# 2  2023
# 3  2023
# 4  2022

# %%
df.describe()
# Out:
#        fatalities     injured  total_victims  age_of_shooter         year
# count  141.000000  141.000000     141.000000      141.000000   141.000000
# mean     7.808511   11.205674      19.007092       34.106383  2010.382979
# std      7.463162   46.579505      51.747532       13.165269    10.796600
# min      3.000000    0.000000       3.000000       11.000000  1982.000000
# 25%      4.000000    1.000000       6.000000       23.000000  2005.000000
# 50%      6.000000    3.000000      10.000000       33.000000  2014.000000
# 75%      8.000000   10.000000      17.000000       43.000000  2018.000000
# max     58.000000  546.000000     604.000000       72.000000  2023.000000

# %%
df.drop_duplicates()
# Out:
#                                       case                   location  \
# 0      Nashville religious school shooting       Nashville, Tennessee
# 1       Michigan State University shooting     East Lansing, Michigan
# 2             Half Moon Bay spree shooting  Half Moon Bay, California
# 3            LA dance studio mass shooting  Monterey Park, California
# 4                Virginia Walmart shooting       Chesapeake, Virginia
# ..                                     ...                        ...
# 136        Shopping centers spree killings          Palm Bay, Florida
# 137  United States Postal Service shooting           Edmond, Oklahoma
# 138         San Ysidro McDonald's massacre     San Ysidro, California
# 139              Dallas nightclub shooting              Dallas, Texas
# 140                  Welding shop shooting             Miami, Florida
#
#            date                                            summary  \
# 0     3/27/2023  Audrey Hale, 28, who was a former student at t...
# 1     2/13/2023  Anthony D. McRae, 43, opened fire at Berkey Ha...
# 2     1/23/2023  Chunli Zhao, 67, suspected of carrying out the...
# 3     1/21/2023  Huu Can Tran, 72, fled the scene in a white va...
# 4    11/22/2022  Andre Bing, 31, who worked as a supervisor at ...
# ..          ...                                                ...
# 136   4/23/1987  Retired librarian William Cruse, 59, was paran...
# 137   8/20/1986  Postal worker Patrick Sherrill, 44, opened fir...
# 138   7/18/1984  James Oliver Huberty, 41, opened fire in a McD...
# 139   6/29/1984  Abdelkrim Belachheb, 39, opened fire at an ups...
# 140   8/20/1982  Junior high school teacher Carl Robert Brown, ...
#
#      fatalities  injured  total_victims location.1  age_of_shooter  \
# 0             6        1              6     School              28
# 1             3        5              8     School              43
# 2             7        1              8       work              67
# 3            11       10             21      Other              72
# 4             6        6             12       work              31
# ..          ...      ...            ...        ...             ...
# 136           6       14             20      Other              59
# 137          15        6             21       work              44
# 138          22       19             41      Other              41
# 139           6        1              7      Other              39
# 140           8        3             11      Other              51
#
#     prior_signs_mental_health_issues  \
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                yes
# 4                                NaN
# ..                               ...
# 136                              Yes
# 137                         Unclear
# 138                              Yes
# 139                              Yes
# 140                              Yes
#
#                                  mental_health_details  \
# 0                                                    -
# 1                                                    -
# 2                                                    -
# 3    According to the LA Times, "Two law enforcemen...
# 4                                                    -
# ..                                                 ...
# 136  He suffered from paranoid delusions. A judge f...
# 137  He was worried he had inherited mental problem...
# 138  The day before the shooting, he tried to make ...
# 139  During his last meal with his wife, he confess...
# 140  His second wife left him because he refused to...
#
#     weapons_obtained_legally  \
# 0                    unknown
# 1                        yes
# 2                    unknown
# 3                    unknown
# 4                    unknown
# ..                       ...
# 136                      Yes
# 137                      Yes
# 138                      Yes
# 139                       No
# 140                      Yes
#
#                                         where_obtained  \
# 0                                                    -
# 1                                                    -
# 2                                                    -
# 3                                                    -
# 4                                                    -
# ..                                                 ...
# 136  Gun store in Norwood, Ohio; The Oaks Trading P...
# 137  Issued by Oklahoma National Guard, where Sherr...
# 138                                            Unknown
# 139         Hines Boulevard Pawn Shop in Dallas, Texas
# 140                 Garcia Gun Center in Hialeah, Fla.
#
#                                            weapon_type  \
# 0           semiautomatic rifle, semiautomatic handgun
# 1                               semiautomatic handguns
# 2                                semiautomatic handgun
# 3       semiautomatic assault weapon (Details pending)
# 4                                semiautomatic handgun
# ..                                                 ...
# 136               One rifle, one revolver, one shotgun
# 137                       Three semiautomatic handguns
# 138  One semiautomatic handgun, one rifle (assault)...
# 139                          One semiautomatic handgun
# 140                                        One shotgun
#
#                                         weapon_details   race  \
# 0                                                    -    NaN
# 1                                                    -  Black
# 2                                                    -  Asian
# 3                                                    -  Asian
# 4                                                    -  Black
# ..                                                 ...    ...
# 136  Sturm, Ruger Mini-14 semiautomatic rifle; 20-g...  white
# 137  .22-caliber, two .45-caliber Colt Model 1911-A...  white
# 138  9mm Browning P35 Hi-Power semiautomatic handgu...  white
# 139       9mm Smith & Wesson 459 semiautomatic handgun  white
# 140  Mossberg 500 Persuader pump-action shotgun wit...  white
#
#                                         gender   type  year
# 0    F (identified as transgender, per police)   Mass  2023
# 1                                            M   Mass  2023
# 2                                            M  Spree  2023
# 3                                            M   Mass  2023
# 4                                            M   Mass  2022
# ..                                         ...    ...   ...
# 136                                       Male  Spree  1987
# 137                                       Male   Mass  1986
# 138                                       Male   Mass  1984
# 139                                       Male   Mass  1984
# 140                                       Male   Mass  1982
#
# [141 rows x 19 columns]

# %%
df.drop(['summary','mental_health_details','case'], axis=1)
# Out:
#                       location        date  fatalities  injured  \
# 0         Nashville, Tennessee   3/27/2023           6        1
# 1       East Lansing, Michigan   2/13/2023           3        5
# 2    Half Moon Bay, California   1/23/2023           7        1
# 3    Monterey Park, California   1/21/2023          11       10
# 4         Chesapeake, Virginia  11/22/2022           6        6
# ..                         ...         ...         ...      ...
# 136          Palm Bay, Florida   4/23/1987           6       14
# 137           Edmond, Oklahoma   8/20/1986          15        6
# 138     San Ysidro, California   7/18/1984          22       19
# 139              Dallas, Texas   6/29/1984           6        1
# 140             Miami, Florida   8/20/1982           8        3
#
#      total_victims location.1  age_of_shooter  \
# 0                6     School              28
# 1                8     School              43
# 2                8       work              67
# 3               21      Other              72
# 4               12       work              31
# ..             ...        ...             ...
# 136             20      Other              59
# 137             21       work              44
# 138             41      Other              41
# 139              7      Other              39
# 140             11      Other              51
#
#     prior_signs_mental_health_issues weapons_obtained_legally  \
# 0                                NaN                  unknown
# 1                                NaN                      yes
# 2                                NaN                  unknown
# 3                                yes                  unknown
# 4                                NaN                  unknown
# ..                               ...                      ...
# 136                              Yes                      Yes
# 137                         Unclear                       Yes
# 138                              Yes                      Yes
# 139                              Yes                       No
# 140                              Yes                      Yes
#
#                                         where_obtained  \
# 0                                                    -
# 1                                                    -
# 2                                                    -
# 3                                                    -
# 4                                                    -
# ..                                                 ...
# 136  Gun store in Norwood, Ohio; The Oaks Trading P...
# 137  Issued by Oklahoma National Guard, where Sherr...
# 138                                            Unknown
# 139         Hines Boulevard Pawn Shop in Dallas, Texas
# 140                 Garcia Gun Center in Hialeah, Fla.
#
#                                            weapon_type  \
# 0           semiautomatic rifle, semiautomatic handgun
# 1                               semiautomatic handguns
# 2                                semiautomatic handgun
# 3       semiautomatic assault weapon (Details pending)
# 4                                semiautomatic handgun
# ..                                                 ...
# 136               One rifle, one revolver, one shotgun
# 137                       Three semiautomatic handguns
# 138  One semiautomatic handgun, one rifle (assault)...
# 139                          One semiautomatic handgun
# 140                                        One shotgun
#
#                                         weapon_details   race  \
# 0                                                    -    NaN
# 1                                                    -  Black
# 2                                                    -  Asian
# 3                                                    -  Asian
# 4                                                    -  Black
# ..                                                 ...    ...
# 136  Sturm, Ruger Mini-14 semiautomatic rifle; 20-g...  white
# 137  .22-caliber, two .45-caliber Colt Model 1911-A...  white
# 138  9mm Browning P35 Hi-Power semiautomatic handgu...  white
# 139       9mm Smith & Wesson 459 semiautomatic handgun  white
# 140  Mossberg 500 Persuader pump-action shotgun wit...  white
#
#                                         gender   type  year
# 0    F (identified as transgender, per police)   Mass  2023
# 1                                            M   Mass  2023
# 2                                            M  Spree  2023
# 3                                            M   Mass  2023
# 4                                            M   Mass  2022
# ..                                         ...    ...   ...
# 136                                       Male  Spree  1987
# 137                                       Male   Mass  1986
# 138                                       Male   Mass  1984
# 139                                       Male   Mass  1984
# 140                                       Male   Mass  1982
#
# [141 rows x 16 columns]

# %%
df.isna().sum()
# Out:
# case                                 0
# location                             0
# date                                 0
# summary                              0
# fatalities                           0
# injured                              0
# total_victims                        0
# location.1                           0
# age_of_shooter                       0
# prior_signs_mental_health_issues    28
# mental_health_details                0
# weapons_obtained_legally             0
# where_obtained                       0
# weapon_type                          0
# weapon_details                       1
# race                                13
# gender                               0
# type                                 0
# year                                 0
# dtype: int64

# %%
df.shape
# Out:
# (141, 19)

# %%
df.info
# Out:
# <bound method DataFrame.info of                                       case                   location  \
# 0      Nashville religious school shooting       Nashville, Tennessee
# 1       Michigan State University shooting     East Lansing, Michigan
# 2             Half Moon Bay spree shooting  Half Moon Bay, California
# 3            LA dance studio mass shooting  Monterey Park, California
# 4                Virginia Walmart shooting       Chesapeake, Virginia
# ..                                     ...                        ...
# 136        Shopping centers spree killings          Palm Bay, Florida
# 137  United States Postal Service shooting           Edmond, Oklahoma
# 138         San Ysidro McDonald's massacre     San Ysidro, California
# 139              Dallas nightclub shooting              Dallas, Texas
# 140                  Welding shop shooting             Miami, Florida
#
#            date                                            summary  \
# 0     3/27/2023  Audrey Hale, 28, who was a former student at t...
# 1     2/13/2023  Anthony D. McRae, 43, opened fire at Berkey Ha...
# 2     1/23/2023  Chunli Zhao, 67, suspected of carrying out the...
# 3     1/21/2023  Huu Can Tran, 72, fled the scene in a white va...
# 4    11/22/2022  Andre Bing, 31, who worked as a supervisor at ...
# ..          ...                                                ...
# 136   4/23/1987  Retired librarian William Cruse, 59, was paran...
# 137   8/20/1986  Postal worker Patrick Sherrill, 44, opened fir...
# 138   7/18/1984  James Oliver Huberty, 41, opened fire in a McD...
# 139   6/29/1984  Abdelkrim Belachheb, 39, opened fire at an ups...
# 140   8/20/1982  Junior high school teacher Carl Robert Brown, ...
#
#      fatalities  injured  total_victims location.1  age_of_shooter  \
# 0             6        1              6     School              28
# 1             3        5              8     School              43
# 2             7        1              8       work              67
# 3            11       10             21      Other              72
# 4             6        6             12       work              31
# ..          ...      ...            ...        ...             ...
# 136           6       14             20      Other              59
# 137          15        6             21       work              44
# 138          22       19             41      Other              41
# 139           6        1              7      Other              39
# 140           8        3             11      Other              51
#
#     prior_signs_mental_health_issues  \
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                yes
# 4                                NaN
# ..                               ...
# 136                              Yes
# 137                         Unclear
# 138                              Yes
# 139                              Yes
# 140                              Yes
#
#                                  mental_health_details  \
# 0                                                    -
# 1                                                    -
# 2                                                    -
# 3    According to the LA Times, "Two law enforcemen...
# 4                                                    -
# ..                                                 ...
# 136  He suffered from paranoid delusions. A judge f...
# 137  He was worried he had inherited mental problem...
# 138  The day before the shooting, he tried to make ...
# 139  During his last meal with his wife, he confess...
# 140  His second wife left him because he refused to...
#
#     weapons_obtained_legally  \
# 0                    unknown
# 1                        yes
# 2                    unknown
# 3                    unknown
# 4                    unknown
# ..                       ...
# 136                      Yes
# 137                      Yes
# 138                      Yes
# 139                       No
# 140                      Yes
#
#                                         where_obtained  \
# 0                                                    -
# 1                                                    -
# 2                                                    -
# 3                                                    -
# 4                                                    -
# ..                                                 ...
# 136  Gun store in Norwood, Ohio; The Oaks Trading P...
# 137  Issued by Oklahoma National Guard, where Sherr...
# 138                                            Unknown
# 139         Hines Boulevard Pawn Shop in Dallas, Texas
# 140                 Garcia Gun Center in Hialeah, Fla.
#
#                                            weapon_type  \
# 0           semiautomatic rifle, semiautomatic handgun
# 1                               semiautomatic handguns
# 2                                semiautomatic handgun
# 3       semiautomatic assault weapon (Details pending)
# 4                                semiautomatic handgun
# ..                                                 ...
# 136               One rifle, one revolver, one shotgun
# 137                       Three semiautomatic handguns
# 138  One semiautomatic handgun, one rifle (assault)...
# 139                          One semiautomatic handgun
# 140                                        One shotgun
#
#                                         weapon_details   race  \
# 0                                                    -    NaN
# 1                                                    -  Black
# 2                                                    -  Asian
# 3                                                    -  Asian
# 4                                                    -  Black
# ..                                                 ...    ...
# 136  Sturm, Ruger Mini-14 semiautomatic rifle; 20-g...  white
# 137  .22-caliber, two .45-caliber Colt Model 1911-A...  white
# 138  9mm Browning P35 Hi-Power semiautomatic handgu...  white
# 139       9mm Smith & Wesson 459 semiautomatic handgun  white
# 140  Mossberg 500 Persuader pump-action shotgun wit...  white
#
#                                         gender   type  year
# 0    F (identified as transgender, per police)   Mass  2023
# 1                                            M   Mass  2023
# 2                                            M  Spree  2023
# 3                                            M   Mass  2023
# 4                                            M   Mass  2022
# ..                                         ...    ...   ...
# 136                                       Male  Spree  1987
# 137                                       Male   Mass  1986
# 138                                       Male   Mass  1984
# 139                                       Male   Mass  1984
# 140                                       Male   Mass  1982
#
# [141 rows x 19 columns]>

# %%
df.dtypes
# Out:
# case                                object
# location                            object
# date                                object
# summary                             object
# fatalities                           int64
# injured                              int64
# total_victims                        int64
# location.1                          object
# age_of_shooter                       int64
# prior_signs_mental_health_issues    object
# mental_health_details               object
# weapons_obtained_legally            object
# where_obtained                      object
# weapon_type                         object
# weapon_details                      object
# race                                object
# gender                              object
# type                                object
# year                                 int64
# dtype: object

# %%
df['location'] = df['location'].astype('string')
df['summary'] = df['summary'].astype('string')
df['location.1'] = df['location.1'].astype('string')
df['where_obtained'] = df['where_obtained'].astype('string')
df['weapon_type']=df['weapon_type'].astype('string')
df['weapon_details']=df['weapon_details'].astype('string')
df['race']=df['race'].astype('string')
df['gender']=df['gender'].astype('string')
df['type']=df['type'].astype('string')

# %%
df.dtypes
# Out:
# case                                object
# location                            string
# date                                object
# summary                             string
# fatalities                           int64
# injured                              int64
# total_victims                        int64
# location.1                          string
# age_of_shooter                       int64
# prior_signs_mental_health_issues    object
# mental_health_details               object
# weapons_obtained_legally            object
# where_obtained                      string
# weapon_type                         string
# weapon_details                      string
# race                                string
# gender                              string
# type                                string
# year                                 int64
# dtype: object

# %%
df[['Month','Day','year']] = df['date'].str.split('/', expand=True)
df[['City','State']] = df['location'].str.split(',',1, expand=True)
df.head(2)
# Out:
#                                   case                location       date  \
# 0  Nashville religious school shooting    Nashville, Tennessee  3/27/2023
# 1   Michigan State University shooting  East Lansing, Michigan  2/13/2023
#
#                                              summary  fatalities  injured  \
# 0  Audrey Hale, 28, who was a former student at t...           6        1
# 1  Anthony D. McRae, 43, opened fire at Berkey Ha...           3        5
#
#    total_victims location.1  age_of_shooter prior_signs_mental_health_issues  \
# 0              6     School              28                              NaN
# 1              8     School              43                              NaN
#
#    ...                                 weapon_type weapon_details   race  \
# 0  ...  semiautomatic rifle, semiautomatic handgun              -   <NA>
# 1  ...                      semiautomatic handguns              -  Black
#
#                                       gender  type  year Month Day  \
# 0  F (identified as transgender, per police)  Mass  2023     3  27
# 1                                          M  Mass  2023     2  13
#
#            City       State
# 0     Nashville   Tennessee
# 1  East Lansing    Michigan
#
# [2 rows x 23 columns]

# %%
df.drop(['case'],axis=1)
# Out:
#                       location        date  \
# 0         Nashville, Tennessee   3/27/2023
# 1       East Lansing, Michigan   2/13/2023
# 2    Half Moon Bay, California   1/23/2023
# 3    Monterey Park, California   1/21/2023
# 4         Chesapeake, Virginia  11/22/2022
# ..                         ...         ...
# 136          Palm Bay, Florida   4/23/1987
# 137           Edmond, Oklahoma   8/20/1986
# 138     San Ysidro, California   7/18/1984
# 139              Dallas, Texas   6/29/1984
# 140             Miami, Florida   8/20/1982
#
#                                                summary  fatalities  injured  \
# 0    Audrey Hale, 28, who was a former student at t...           6        1
# 1    Anthony D. McRae, 43, opened fire at Berkey Ha...           3        5
# 2    Chunli Zhao, 67, suspected of carrying out the...           7        1
# 3    Huu Can Tran, 72, fled the scene in a white va...          11       10
# 4    Andre Bing, 31, who worked as a supervisor at ...           6        6
# ..                                                 ...         ...      ...
# 136  Retired librarian William Cruse, 59, was paran...           6       14
# 137  Postal worker Patrick Sherrill, 44, opened fir...          15        6
# 138  James Oliver Huberty, 41, opened fire in a McD...          22       19
# 139  Abdelkrim Belachheb, 39, opened fire at an ups...           6        1
# 140  Junior high school teacher Carl Robert Brown, ...           8        3
#
#      total_victims location.1  age_of_shooter  \
# 0                6     School              28
# 1                8     School              43
# 2                8       work              67
# 3               21      Other              72
# 4               12       work              31
# ..             ...        ...             ...
# 136             20      Other              59
# 137             21       work              44
# 138             41      Other              41
# 139              7      Other              39
# 140             11      Other              51
#
#     prior_signs_mental_health_issues  \
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                yes
# 4                                NaN
# ..                               ...
# 136                              Yes
# 137                         Unclear
# 138                              Yes
# 139                              Yes
# 140                              Yes
#
#                                  mental_health_details  ...  \
# 0                                                    -  ...
# 1                                                    -  ...
# 2                                                    -  ...
# 3    According to the LA Times, "Two law enforcemen...  ...
# 4                                                    -  ...
# ..                                                 ...  ...
# 136  He suffered from paranoid delusions. A judge f...  ...
# 137  He was worried he had inherited mental problem...  ...
# 138  The day before the shooting, he tried to make ...  ...
# 139  During his last meal with his wife, he confess...  ...
# 140  His second wife left him because he refused to...  ...
#
#                                            weapon_type  \
# 0           semiautomatic rifle, semiautomatic handgun
# 1                               semiautomatic handguns
# 2                                semiautomatic handgun
# 3       semiautomatic assault weapon (Details pending)
# 4                                semiautomatic handgun
# ..                                                 ...
# 136               One rifle, one revolver, one shotgun
# 137                       Three semiautomatic handguns
# 138  One semiautomatic handgun, one rifle (assault)...
# 139                          One semiautomatic handgun
# 140                                        One shotgun
#
#                                         weapon_details   race  \
# 0                                                    -   <NA>
# 1                                                    -  Black
# 2                                                    -  Asian
# 3                                                    -  Asian
# 4                                                    -  Black
# ..                                                 ...    ...
# 136  Sturm, Ruger Mini-14 semiautomatic rifle; 20-g...  white
# 137  .22-caliber, two .45-caliber Colt Model 1911-A...  white
# 138  9mm Browning P35 Hi-Power semiautomatic handgu...  white
# 139       9mm Smith & Wesson 459 semiautomatic handgun  white
# 140  Mossberg 500 Persuader pump-action shotgun wit...  white
#
#                                         gender   type  year Month Day  \
# 0    F (identified as transgender, per police)   Mass  2023     3  27
# 1                                            M   Mass  2023     2  13
# 2                                            M  Spree  2023     1  23
# 3                                            M   Mass  2023     1  21
# 4                                            M   Mass  2022    11  22
# ..                                         ...    ...   ...   ...  ..
# 136                                       Male  Spree  1987     4  23
# 137                                       Male   Mass  1986     8  20
# 138                                       Male   Mass  1984     7  18
# 139                                       Male   Mass  1984     6  29
# 140                                       Male   Mass  1982     8  20
#
#               City        State
# 0        Nashville    Tennessee
# 1     East Lansing     Michigan
# 2    Half Moon Bay   California
# 3    Monterey Park   California
# 4       Chesapeake     Virginia
# ..             ...          ...
# 136       Palm Bay      Florida
# 137         Edmond     Oklahoma
# 138     San Ysidro   California
# 139         Dallas        Texas
# 140          Miami      Florida
#
# [141 rows x 22 columns]

# %%
df.groupby('State')[['total_victims', 'injured', 'fatalities']].sum().sort_values(['total_victims'], ascending=False).head(15).style.background_gradient(cmap='Reds')
# Out:
# <style  type="text/css" >
# #T_5c76f_row0_col0,#T_5c76f_row0_col1,#T_5c76f_row1_col2{
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }#T_5c76f_row0_col2{
#             background-color:  #fca78b;
#             color:  #000000;
#         }#T_5c76f_row1_col0{
#             background-color:  #f85d42;
#             color:  #000000;
#         }#T_5c76f_row1_col1{
#             background-color:  #fcaa8d;
#             color:  #000000;
#         }#T_5c76f_row2_col0{
#             background-color:  #fa6547;
#             color:  #000000;
#         }#T_5c76f_row2_col1{
#             background-color:  #fca285;
#             color:  #000000;
#         }#T_5c76f_row2_col2{
#             background-color:  #ab1016;
#             color:  #f1f1f1;
#         }#T_5c76f_row3_col0{
#             background-color:  #fc9d7f;
#             color:  #000000;
#         }#T_5c76f_row3_col1{
#             background-color:  #fdcdb9;
#             color:  #000000;
#         }#T_5c76f_row3_col2{
#             background-color:  #da2723;
#             color:  #f1f1f1;
#         }#T_5c76f_row4_col0{
#             background-color:  #fcbba1;
#             color:  #000000;
#         }#T_5c76f_row4_col1{
#             background-color:  #fcc3ab;
#             color:  #000000;
#         }#T_5c76f_row4_col2,#T_5c76f_row6_col2{
#             background-color:  #fcbca2;
#             color:  #000000;
#         }#T_5c76f_row5_col0{
#             background-color:  #fee3d6;
#             color:  #000000;
#         }#T_5c76f_row5_col1{
#             background-color:  #fedfd0;
#             color:  #000000;
#         }#T_5c76f_row5_col2{
#             background-color:  #fee9df;
#             color:  #000000;
#         }#T_5c76f_row6_col0,#T_5c76f_row12_col2{
#             background-color:  #fee7db;
#             color:  #000000;
#         }#T_5c76f_row6_col1,#T_5c76f_row9_col1{
#             background-color:  #ffece3;
#             color:  #000000;
#         }#T_5c76f_row7_col0,#T_5c76f_row10_col1{
#             background-color:  #ffece4;
#             color:  #000000;
#         }#T_5c76f_row7_col1,#T_5c76f_row8_col1{
#             background-color:  #ffeee7;
#             color:  #000000;
#         }#T_5c76f_row7_col2{
#             background-color:  #fdd4c2;
#             color:  #000000;
#         }#T_5c76f_row8_col0{
#             background-color:  #ffede5;
#             color:  #000000;
#         }#T_5c76f_row8_col2{
#             background-color:  #fedaca;
#             color:  #000000;
#         }#T_5c76f_row9_col0{
#             background-color:  #fff0e8;
#             color:  #000000;
#         }#T_5c76f_row9_col2{
#             background-color:  #ffeee6;
#             color:  #000000;
#         }#T_5c76f_row10_col0{
#             background-color:  #fff2ec;
#             color:  #000000;
#         }#T_5c76f_row10_col2,#T_5c76f_row11_col1,#T_5c76f_row13_col0,#T_5c76f_row14_col0{
#             background-color:  #fff5f0;
#             color:  #000000;
#         }#T_5c76f_row11_col0,#T_5c76f_row12_col1{
#             background-color:  #fff3ed;
#             color:  #000000;
#         }#T_5c76f_row11_col2{
#             background-color:  #fdd2bf;
#             color:  #000000;
#         }#T_5c76f_row12_col0,#T_5c76f_row13_col1{
#             background-color:  #fff4ef;
#             color:  #000000;
#         }#T_5c76f_row13_col2{
#             background-color:  #fee6da;
#             color:  #000000;
#         }#T_5c76f_row14_col1{
#             background-color:  #fff1ea;
#             color:  #000000;
#         }#T_5c76f_row14_col2{
#             background-color:  #fff0e9;
#             color:  #000000;
#         }</style><table id="T_5c76f_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >total_victims</th>        <th class="col_heading level0 col1" >injured</th>        <th class="col_heading level0 col2" >fatalities</th>    </tr>    <tr>        <th class="index_name level0" >State</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_5c76f_level0_row0" class="row_heading level0 row0" > Nevada</th>
#                         <td id="T_5c76f_row0_col0" class="data row0 col0" >616</td>
#                         <td id="T_5c76f_row0_col1" class="data row0 col1" >553</td>
#                         <td id="T_5c76f_row0_col2" class="data row0 col2" >63</td>
#             </tr>
#             <tr>
#                         <th id="T_5c76f_level0_row1" class="row_heading level0 row1" > California</th>
#                         <td id="T_5c76f_row1_col0" class="data row1 col0" >346</td>
#                         <td id="T_5c76f_row1_col1" class="data row1 col1" >171</td>
#                         <td id="T_5c76f_row1_col2" class="data row1 col2" >175</td>
#             </tr>
#             <tr>
#                         <th id="T_5c76f_level0_row2" class="row_heading level0 row2" > Texas</th>
#                         <td id="T_5c76f_row2_col0" class="data row2 col0" >334</td>
#                         <td id="T_5c76f_row2_col1" class="data row2 col1" >183</td>
#                         <td id="T_5c76f_row2_col2" class="data row2 col2" >151</td>
#             </tr>
#             <tr>
#                         <th id="T_5c76f_level0_row3" class="row_heading level0 row3" > Florida</th>
#                         <td id="T_5c76f_row3_col0" class="data row3 col0" >235</td>
#                         <td id="T_5c76f_row3_col1" class="data row3 col1" >109</td>
#                         <td id="T_5c76f_row3_col2" class="data row3 col2" >126</td>
#             </tr>
#             <tr>
#                         <th id="T_5c76f_level0_row4" class="row_heading level0 row4" > Colorado</th>
#                         <td id="T_5c76f_row4_col0" class="data row4 col0" >182</td>
#                         <td id="T_5c76f_row4_col1" class="data row4 col1" >129</td>
#                         <td id="T_5c76f_row4_col2" class="data row4 col2" >53</td>
#             </tr>
#             <tr>
#                         <th id="T_5c76f_level0_row5" class="row_heading level0 row5" > Illinois</th>
#                         <td id="T_5c76f_row5_col0" class="data row5 col0" >102</td>
#                         <td id="T_5c76f_row5_col1" class="data row5 col1" >77</td>
#                         <td id="T_5c76f_row5_col2" class="data row5 col2" >25</td>
#             </tr>
#             <tr>
#                         <th id="T_5c76f_level0_row6" class="row_heading level0 row6" > Virginia</th>
#                         <td id="T_5c76f_row6_col0" class="data row6 col0" >88</td>
#                         <td id="T_5c76f_row6_col1" class="data row6 col1" >35</td>
#                         <td id="T_5c76f_row6_col2" class="data row6 col2" >53</td>
#             </tr>
#             <tr>
#                         <th id="T_5c76f_level0_row7" class="row_heading level0 row7" > New York</th>
#                         <td id="T_5c76f_row7_col0" class="data row7 col0" >68</td>
#                         <td id="T_5c76f_row7_col1" class="data row7 col1" >28</td>
#                         <td id="T_5c76f_row7_col2" class="data row7 col2" >40</td>
#             </tr>
#             <tr>
#                         <th id="T_5c76f_level0_row8" class="row_heading level0 row8" > Washington</th>
#                         <td id="T_5c76f_row8_col0" class="data row8 col0" >65</td>
#                         <td id="T_5c76f_row8_col1" class="data row8 col1" >28</td>
#                         <td id="T_5c76f_row8_col2" class="data row8 col2" >37</td>
#             </tr>
#             <tr>
#                         <th id="T_5c76f_level0_row9" class="row_heading level0 row9" > Ohio</th>
#                         <td id="T_5c76f_row9_col0" class="data row9 col0" >56</td>
#                         <td id="T_5c76f_row9_col1" class="data row9 col1" >36</td>
#                         <td id="T_5c76f_row9_col2" class="data row9 col2" >20</td>
#             </tr>
#             <tr>
#                         <th id="T_5c76f_level0_row10" class="row_heading level0 row10" > Oregon</th>
#                         <td id="T_5c76f_row10_col0" class="data ro

# %%
df.columns
# Out:
# Index(['case', 'location', 'date', 'summary', 'fatalities', 'injured',
#        'total_victims', 'location.1', 'age_of_shooter',
#        'prior_signs_mental_health_issues', 'mental_health_details',
#        'weapons_obtained_legally', 'where_obtained', 'weapon_type',
#        'weapon_details', 'race', 'gender', 'type', 'year', 'Month', 'Day',
#        'City', 'State'],
#       dtype='object')

# %%
df.groupby('year')[['total_victims', 'injured', 'fatalities']].sum().sort_values(['total_victims'], ascending=False).head(15).style.background_gradient(cmap='Blues')
# Out:
# <style  type="text/css" >
# #T_642b0_row0_col0,#T_642b0_row0_col1,#T_642b0_row0_col2{
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }#T_642b0_row1_col0,#T_642b0_row10_col2{
#             background-color:  #cfe1f2;
#             color:  #000000;
#         }#T_642b0_row1_col1{
#             background-color:  #d6e5f4;
#             color:  #000000;
#         }#T_642b0_row1_col2{
#             background-color:  #539ecd;
#             color:  #000000;
#         }#T_642b0_row2_col0{
#             background-color:  #d0e2f2;
#             color:  #000000;
#         }#T_642b0_row2_col1,#T_642b0_row4_col0,#T_642b0_row5_col0{
#             background-color:  #d9e7f5;
#             color:  #000000;
#         }#T_642b0_row2_col2{
#             background-color:  #4f9bcb;
#             color:  #000000;
#         }#T_642b0_row3_col0{
#             background-color:  #d8e7f5;
#             color:  #000000;
#         }#T_642b0_row3_col1{
#             background-color:  #dfecf7;
#             color:  #000000;
#         }#T_642b0_row3_col2,#T_642b0_row4_col2{
#             background-color:  #5aa2cf;
#             color:  #000000;
#         }#T_642b0_row4_col1{
#             background-color:  #e1edf8;
#             color:  #000000;
#         }#T_642b0_row5_col1{
#             background-color:  #e4eff9;
#             color:  #000000;
#         }#T_642b0_row5_col2{
#             background-color:  #3d8dc4;
#             color:  #000000;
#         }#T_642b0_row6_col0,#T_642b0_row7_col0{
#             background-color:  #ebf3fb;
#             color:  #000000;
#         }#T_642b0_row6_col1,#T_642b0_row13_col1{
#             background-color:  #eef5fc;
#             color:  #000000;
#         }#T_642b0_row6_col2{
#             background-color:  #b3d3e8;
#             color:  #000000;
#         }#T_642b0_row7_col1,#T_642b0_row8_col0{
#             background-color:  #edf4fc;
#             color:  #000000;
#         }#T_642b0_row7_col2{
#             background-color:  #bfd8ed;
#             color:  #000000;
#         }#T_642b0_row8_col1{
#             background-color:  #f2f7fd;
#             color:  #000000;
#         }#T_642b0_row8_col2{
#             background-color:  #9dcae1;
#             color:  #000000;
#         }#T_642b0_row9_col0,#T_642b0_row9_col1{
#             background-color:  #eff6fc;
#             color:  #000000;
#         }#T_642b0_row9_col2{
#             background-color:  #c7dcef;
#             color:  #000000;
#         }#T_642b0_row10_col0,#T_642b0_row10_col1{
#             background-color:  #f4f9fe;
#             color:  #000000;
#         }#T_642b0_row11_col0{
#             background-color:  #f5f9fe;
#             color:  #000000;
#         }#T_642b0_row11_col1,#T_642b0_row14_col0,#T_642b0_row14_col2{
#             background-color:  #f7fbff;
#             color:  #000000;
#         }#T_642b0_row11_col2{
#             background-color:  #bcd7eb;
#             color:  #000000;
#         }#T_642b0_row12_col0,#T_642b0_row13_col0,#T_642b0_row13_col2{
#             background-color:  #f5fafe;
#             color:  #000000;
#         }#T_642b0_row12_col1,#T_642b0_row14_col1{
#             background-color:  #f1f7fd;
#             color:  #000000;
#         }#T_642b0_row12_col2{
#             background-color:  #e6f0f9;
#             color:  #000000;
#         }</style><table id="T_642b0_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >total_victims</th>        <th class="col_heading level0 col1" >injured</th>        <th class="col_heading level0 col2" >fatalities</th>    </tr>    <tr>        <th class="index_name level0" >year</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_642b0_level0_row0" class="row_heading level0 row0" >2017</th>
#                         <td id="T_642b0_row0_col0" class="data row0 col0" >704</td>
#                         <td id="T_642b0_row0_col1" class="data row0 col1" >587</td>
#                         <td id="T_642b0_row0_col2" class="data row0 col2" >117</td>
#             </tr>
#             <tr>
#                         <th id="T_642b0_level0_row1" class="row_heading level0 row1" >2019</th>
#                         <td id="T_642b0_row1_col0" class="data row1 col0" >185</td>
#                         <td id="T_642b0_row1_col1" class="data row1 col1" >112</td>
#                         <td id="T_642b0_row1_col2" class="data row1 col2" >73</td>
#             </tr>
#             <tr>
#                         <th id="T_642b0_level0_row2" class="row_heading level0 row2" >2022</th>
#                         <td id="T_642b0_row2_col0" class="data row2 col0" >178</td>
#                         <td id="T_642b0_row2_col1" class="data row2 col1" >104</td>
#                         <td id="T_642b0_row2_col2" class="data row2 col2" >74</td>
#             </tr>
#             <tr>
#                         <th id="T_642b0_level0_row3" class="row_heading level0 row3" >2016</th>
#                         <td id="T_642b0_row3_col0" class="data row3 col0" >154</td>
#                         <td id="T_642b0_row3_col1" class="data row3 col1" >83</td>
#                         <td id="T_642b0_row3_col2" class="data row3 col2" >71</td>
#             </tr>
#             <tr>
#                         <th id="T_642b0_level0_row4" class="row_heading level0 row4" >2012</th>
#                         <td id="T_642b0_row4_col0" class="data row4 col0" >151</td>
#                         <td id="T_642b0_row4_col1" class="data row4 col1" >80</td>
#                         <td id="T_642b0_row4_col2" class="data row4 col2" >71</td>
#             </tr>
#             <tr>
#                         <th id="T_642b0_level0_row5" class="row_heading level0 row5" >2018</th>
#                         <td id="T_642b0_row5_col0" class="data row5 col0" >150</td>
#                         <td id="T_642b0_row5_col1" class="data row5 col1" >70</td>
#                         <td id="T_642b0_row5_col2" class="data row5 col2" >80</td>
#             </tr>
#             <tr>
#                         <th id="T_642b0_level0_row6" class="row_heading level0 row6" >2015</th>
#                         <td id="T_642b0_row6_col0" class="data row6 col0" >89</td>
#                         <td id="T_642b0_row6_col1" class="data row6 col1" >43</td>
#                         <td id="T_642b0_row6_col2" class="data row6 col2" >46</td>
#             </tr>
#             <tr>
#                         <th id="T_642b0_level0_row7" class="row_heading level0 row7" >1999</th>
#                         <td id="T_642b0_row7_col0" class="data row7 col0" >89</td>
#                         <td id="T_642b0_row7_col1" class="data row7 col1" >47</td>
#                         <td id="T_642b0_row7_col2" class="data row7 col2" >42</td>
#             </tr>
#             <tr>
#                         <th id="T_642b0_level0_row8" class="row_heading level0 row8" >2007</th>
#                         <td id="T_642b0_row8_col0" class="data row8 col0" >85</td>
#                         <td id="T_642b0_row8_col1" class="data row8 col1" >32</td>
#                         <td id="T_642b0_row8_col2" class="data row8 col2" >53</td>
#             </tr>
#             <tr>
#                         <th id="T_642b0_level0_row9" class="row_heading level0 row9" >2009</th>
#                         <td id="T_642b0_row9_col0" class="data row9 col0" >78</td>
#                         <td id="T_642b0_row9_col1" class="data row9 col1" >39</td>
#                         <td id="T_642b0_row9_col2" class="data row9 col2" >39</td>
#             </tr>
#             <tr>
#                         <th id="T_642b0_level0_row10" class="row_heading level0 row10" >1991</th>
#                         <td id="T_642b0_row10_col0" class="data row10 col0" >61</td>
#                         <td id="T_642b0_row10_col1" class="data row10 col1" >26</td>
#                         <td id="T_642b0_row10_col2" class="data row10 col2" >35</td>
#             </tr>
#             <tr>
#                         <th id="T_642b0_level0_row11" class="row_heading level0 row11" >2021</th>
#                         <td id="T_642b0_row11_

# %%
df['gender'] = df['gender'].replace('M', 'Male')
df['gender'] = df['gender'].replace('F', 'Female')

# %%
df['gender'].value_counts()
plt.figure(figsize=(10,10))
df['gender'].value_counts().plot.pie(explode=None, autopct = '%1.1f%%')
plt.title('Gender distribution')
# Out:
# Text(0.5, 1.0, 'Gender distribution')

# %%
Injured = df.groupby('State')['injured'].sum().sort_values(ascending=False).head(15)

plt.figure(figsize=(18,5))
sns.barplot(Injured.index, Injured.values)
plt.xlabel('State')
plt.ylabel('Number of injured')
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\adika\Downloads\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df["State"].value_counts()
# Out:
#  California        25
#  Florida           12
#  Texas             12
#  Colorado           8
#  Washington         7
#  Wisconsin          5
#  Pennsylvania       5
#  Illinois           5
#  New York           5
#  Michigan           4
#  Ohio               4
#  Maryland           4
#  Virginia           4
#  Georgia            3
#  Connecticut        3
#  Tennessee          3
#  North Carolina     3
#  Missouri           2
#  Minnesota          2
#  South Carolina     2
#  Indiana            2
#  Oregon             2
#  Oklahoma           2
#  Nevada             2
#  Kentucky           2
#  Kansas             1
#  D.C.               1
#  Nebraska           1
#  Iowa               1
#  Arizona            1
#  New Jersey         1
#  Lousiana           1
#  Arkansas           1
#  Alabama            1
#  Massachusetts      1
#  Utah               1
#  Hawaii             1
#  Mississippi        1
# Name: State, dtype: Int64

# %%
Fatalities = df.groupby('State')['fatalities'].sum().sort_values(ascending=False).head(15)

plt.figure(figsize=(18,5))
sns.barplot(Fatalities.index, Fatalities.values)
plt.xlabel('State')
plt.ylabel('Fatalities')
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\adika\Downloads\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df['location.1'] = df['location.1'].replace('Other\n', 'other')
df['location.1'] = df['location.1'].replace('religious', 'Religious')
df['location.1'] = df['location.1'].replace('\nwork', 'work')
df['location.1'] = df['location.1'].replace('Other', 'other')

# %%
print(df['location.1'].unique())
# Out:
# <StringArray>
# ['School', 'work', 'other', 'Religious', 'Military', 'Airport']
# Length: 6, dtype: string

# %%
df['location.1'].value_counts()
plt.figure(figsize=(10,10))
df['location.1'].value_counts().plot.pie(explode=None, autopct = '%1.1f%%')
plt.title('Types of locations')
# Out:
# Text(0.5, 1.0, 'Types of locations')

# %%
df['race'] = df['race'].replace('white', 'White')
df['race'] = df['race'].replace('Black','black')
df['race'] = df['race'].replace('unclear','Other')
df['race'] = df['race'].replace('White ', 'White')

# %%
df['race'].unique()
# Out:
# <StringArray>
# [<NA>, 'black', 'Asian', 'White', 'Latino', 'Other', 'Native American']
# Length: 7, dtype: string

# %%
df['race'].value_counts()
plt.figure(figsize=(10,8))
df['race'].value_counts().plot.pie(explode=None, autopct = '%1.1f%%', shadow=False)
plt.title('Race of the shooter')
# Out:
# Text(0.5, 1.0, 'Race of the shooter')

# %%
df['prior_signs_mental_health_issues'] = df['prior_signs_mental_health_issues'].replace('', 'unknown')
df['prior_signs_mental_health_issues'] = df['prior_signs_mental_health_issues'].replace('Yes', 'yes')
df['prior_signs_mental_health_issues'] = df['prior_signs_mental_health_issues'].replace('Unclear', 'unknown')
df['prior_signs_mental_health_issues'] = df['prior_signs_mental_health_issues'].replace('TBD', 'unknown')
df['prior_signs_mental_health_issues'] = df['prior_signs_mental_health_issues'].replace('Unknown', 'unknown')

# %%
df['prior_signs_mental_health_issues'].value_counts()
plt.figure(figsize=(10,10))
df['prior_signs_mental_health_issues'].value_counts().plot.pie(explode=None, autopct = '%1.1f%%', shadow=False)
plt.title('prior_signs_mental_health_issues')
# Out:
# Text(0.5, 1.0, 'prior_signs_mental_health_issues')

# %%
Injured = df.groupby('City')['injured'].sum().sort_values(ascending=False).head(15)

plt.figure(figsize=(18,5))
sns.barplot(Injured.index, Injured.values)
plt.xlabel('City')
plt.ylabel('Number of injured')
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\adika\Downloads\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
Fatalities = df.groupby('City')['fatalities'].sum().sort_values(ascending=False).head(15)

plt.figure(figsize=(18,5))
sns.barplot(Fatalities.index, Fatalities.values)
plt.xlabel('City')
plt.ylabel('Fatalities')
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\adika\Downloads\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df['weapon_type'].unique
# Out:
# <bound method Series.unique of 0             semiautomatic rifle, semiautomatic handgun
# 1                                 semiautomatic handguns
# 2                                  semiautomatic handgun
# 3         semiautomatic assault weapon (Details pending)
# 4                                  semiautomatic handgun
#                              ...
# 136                 One rifle, one revolver, one shotgun
# 137                         Three semiautomatic handguns
# 138    One semiautomatic handgun, one rifle (assault)...
# 139                            One semiautomatic handgun
# 140                                          One shotgun
# Name: weapon_type, Length: 141, dtype: string>

# %%
df.dtypes
# Out:
# case                                object
# location                            string
# date                                object
# summary                             string
# fatalities                           int64
# injured                              int64
# total_victims                        int64
# location.1                          string
# age_of_shooter                       int64
# prior_signs_mental_health_issues    object
# mental_health_details               object
# weapons_obtained_legally            object
# where_obtained                      string
# weapon_type                         string
# weapon_details                      string
# race                                string
# gender                              string
# type                                string
# year                                object
# Month                               object
# Day                                 object
# City                                string
# State                               string
# dtype: object

# %%
df['weapons_obtained_legally'] = df['weapons_obtained_legally'].astype('string')

# %%
df['weapons_obtained_legally'].unique()
# Out:
# <StringArray>
# [                                                                                                                            'unknown',
#                                                                                                                                  'yes',
#                                                                                                                                  'Yes',
#                                                                                                                                   'No',
#                                                                                                                                  'TBD',
#  'Kelley passed federal criminal background checks; the US Air Force failed to provide information on his criminal history to the FBI',
#                                                                                                                              'Unknown',
#                                                                                                                                '\nYes',
#                                                'Yes ("some of the weapons were purchased legally and some of them may not have been")',
#                                                                                                                                 'Yes ']
# Length: 10, dtype: string

# %%
df['weapons_obtained_legally'] = df['weapons_obtained_legally'].replace('Unknown', 'unknown')
df['weapons_obtained_legally'] = df['weapons_obtained_legally'].replace('Yes', 'yes')
df['weapons_obtained_legally'] = df['weapons_obtained_legally'].replace('TBD', 'unknown')
df['weapons_obtained_legally'] = df['weapons_obtained_legally'].replace('Kelley passed federal criminal background checks; the US Air Force failed to provide information on his criminal history to the FBI', 'unknown')
df['weapons_obtained_legally'] = df['weapons_obtained_legally'].replace('\nYes', 'yes')
df['weapons_obtained_legally'] = df['weapons_obtained_legally'].replace('Yes ("some of the weapons were purchased legally and some of them may not have been")', 'yes')
df['weapons_obtained_legally'] = df['weapons_obtained_legally'].replace('Yes ', 'yes')

# %%
df['weapons_obtained_legally'].value_counts()
plt.figure(figsize=(10,8))
df['weapons_obtained_legally'].value_counts().plot.pie(explode=None, autopct = '%1.1f%%', shadow=False)
plt.title('weapons_obtained_legally')
# Out:
# Text(0.5, 1.0, 'weapons_obtained_legally')

# %%
Types = df['type']

plt.figure(figsize=(10,5))
sns.barplot(Types.values, Types.index)
plt.xlabel('Type')
plt.ylabel('Fatalities')
plt.xticks()
plt.show()
# Out:
# C:\Users\adika\Downloads\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
fatalities_per_year = df.groupby("year")["fatalities"].sum()

plt.figure(figsize=(20,6))
sns.barplot(fatalities_per_year.index, fatalities_per_year.values)
plt.xlabel("Fatalities per year", fontsize=20)
plt.ylabel("Count", fontsize=20)
# Out:
# C:\Users\adika\Downloads\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0, 0.5, 'Count')

# %%
fatalities_per_year = df.groupby("Month")["fatalities"].sum()

plt.figure(figsize=(20,6))
sns.barplot(fatalities_per_year.index, fatalities_per_year.values)
plt.xlabel("Fatalities per month", fontsize=20)
plt.ylabel("Count", fontsize=20)
# Out:
# C:\Users\adika\Downloads\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0, 0.5, 'Count')

# %%
def divide_ages_into_groups(df, column_name):
    # Define the age ranges and corresponding labels
    age_ranges = [
        (0, 17, 'Child'),
        (18, 25, 'Young Adult'),
        (26, 40, 'Adult'),
        (41, 60, 'Middle-aged'),
        (61, float('inf'), 'Senior')
    ]

    # Create a new column to store the age groups
    df['Age Group'] = ''

    # Iterate over each row in the DataFrame
    for index, row in df.iterrows():
        age = row[column_name]

        # Check the age against each age range
        for range_start, range_end, group_label in age_ranges:
            if range_start <= age <= range_end:
                df.at[index, 'Age Group'] = group_label
                break

    return df

# %%
df = divide_ages_into_groups(df, 'age_of_shooter')

# %%
print(df)
# Out:
#                                       case                   location  \
# 0      Nashville religious school shooting       Nashville, Tennessee
# 1       Michigan State University shooting     East Lansing, Michigan
# 2             Half Moon Bay spree shooting  Half Moon Bay, California
# 3            LA dance studio mass shooting  Monterey Park, California
# 4                Virginia Walmart shooting       Chesapeake, Virginia
# ..                                     ...                        ...
# 136        Shopping centers spree killings          Palm Bay, Florida
# 137  United States Postal Service shooting           Edmond, Oklahoma
# 138         San Ysidro McDonald's massacre     San Ysidro, California
# 139              Dallas nightclub shooting              Dallas, Texas
# 140                  Welding shop shooting             Miami, Florida
#
#            date                                            summary  \
# 0     3/27/2023  Audrey Hale, 28, who was a former student at t...
# 1     2/13/2023  Anthony D. McRae, 43, opened fire at Berkey Ha...
# 2     1/23/2023  Chunli Zhao, 67, suspected of carrying out the...
# 3     1/21/2023  Huu Can Tran, 72, fled the scene in a white va...
# 4    11/22/2022  Andre Bing, 31, who worked as a supervisor at ...
# ..          ...                                                ...
# 136   4/23/1987  Retired librarian William Cruse, 59, was paran...
# 137   8/20/1986  Postal worker Patrick Sherrill, 44, opened fir...
# 138   7/18/1984  James Oliver Huberty, 41, opened fire in a McD...
# 139   6/29/1984  Abdelkrim Belachheb, 39, opened fire at an ups...
# 140   8/20/1982  Junior high school teacher Carl Robert Brown, ...
#
#      fatalities  injured  total_victims location.1  age_of_shooter  \
# 0             6        1              6     School              28
# 1             3        5              8     School              43
# 2             7        1              8       work              67
# 3            11       10             21      other              72
# 4             6        6             12       work              31
# ..          ...      ...            ...        ...             ...
# 136           6       14             20      other              59
# 137          15        6             21       work              44
# 138          22       19             41      other              41
# 139           6        1              7      other              39
# 140           8        3             11      other              51
#
#     prior_signs_mental_health_issues  ...  \
# 0                                NaN  ...
# 1                                NaN  ...
# 2                                NaN  ...
# 3                                yes  ...
# 4                                NaN  ...
# ..                               ...  ...
# 136                              yes  ...
# 137                         Unclear   ...
# 138                              yes  ...
# 139                              yes  ...
# 140                              yes  ...
#
#                                         weapon_details   race  \
# 0                                                    -   <NA>
# 1                                                    -  black
# 2                                                    -  Asian
# 3                                                    -  Asian
# 4                                                    -  black
# ..                                                 ...    ...
# 136  Sturm, Ruger Mini-14 semiautomatic rifle; 20-g...  White
# 137  .22-caliber, two .45-caliber Colt Model 1911-A...  White
# 138  9mm Browning P35 Hi-Power semiautomatic handgu...  White
# 139       9mm Smith & Wesson 459 semiautomatic handgun  White
# 140  Mossberg 500 Persuader pump-action shotgun wit...  White
#
#                                         gender   type  year Month Day  \
# 0    F (identified as transgender, per police)   Mass  2023     3  27
# 1                                         Male   Mass  2023     2  13
# 2                                         Male  Spree  2023     1  23
# 3                                         Male   Mass  2023     1  21
# 4                                         Male   Mass  2022    11  22
# ..                                         ...    ...   ...   ...  ..
# 136                                       Male  Spree  1987     4  23
# 137                                       Male   Mass  1986     8  20
# 138                                       Male   Mass  1984     7  18
# 139                                       Male   Mass  1984     6  29
# 140                                       Male   Mass  1982     8  20
#
#               City        State    Age Group
# 0        Nashville    Tennessee        Adult
# 1     East Lansing     Michigan  Middle-aged
# 2    Half Moon Bay   California       Senior
# 3    Monterey Park   California       Senior
# 4       Chesapeake     Virginia        Adult
# ..             ...          ...          ...
# 136       Palm Bay      Florida  Middle-aged
# 137         Edmond     Oklahoma  Middle-aged
# 138     San Ysidro   California  Middle-aged
# 139         Dallas        Texas        Adult
# 140          Miami      Florida  Middle-aged
#
# [141 rows x 24 columns]

# %%
df.dtypes
# Out:
# case                                object
# location                            string
# date                                object
# summary                             string
# fatalities                           int64
# injured                              int64
# total_victims                        int64
# location.1                          string
# age_of_shooter                       int64
# prior_signs_mental_health_issues    object
# mental_health_details               object
# weapons_obtained_legally            object
# where_obtained                      string
# weapon_type                         string
# weapon_details                      string
# race                                string
# gender                              string
# type                                string
# year                                object
# Month                               object
# Day                                 object
# City                                string
# State                               string
# Age Group                           object
# dtype: object

# %%
Ages = df["Age Group"].sort_values(ascending=True)
sns.countplot(x=Ages, data=df)
plt.xlabel("Age Groups", fontsize=20)
plt.ylabel("Count", fontsize=20)
plt.title('Age Demographics', fontsize = 21)
# Out:
# Text(0.5, 1.0, 'Age Demographics')

# %%
Ages
# Out:
# 0           Adult
# 77          Adult
# 30          Adult
# 74          Adult
# 72          Adult
#          ...
# 14    Young Adult
# 13    Young Adult
# 71    Young Adult
# 99    Young Adult
# 97    Young Adult
# Name: Age Group, Length: 141, dtype: object
